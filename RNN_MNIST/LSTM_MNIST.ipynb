# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

#重置default graph计算图以及nodes节点
tf.reset_default_graph()

# 超参数
learning_rate = 0.01    # 学习率
n_steps = 28            # LSTM 展开步数（时序持续长度）
n_inputs = 28           # 输入节点数
n_hiddens = 64          # 隐层节点数
n_layers = 2            # LSTM layer 层数
n_classes = 10          # 输出节点数（分类数目）

# 加载数据
mnist = input_data.read_data_sets("E:\sxl_Programs\Python\MNIST_data\MNIST_data", one_hot=True)
test_x = mnist.test.images
test_y = mnist.test.labels

# tensor placeholder
with tf.name_scope('inputs'):
    x = tf.placeholder(tf.float32, [None, n_steps * n_inputs], name='x_input')     # 输入
    y = tf.placeholder(tf.float32, [None, n_classes], name='y_input')               # 输出
    keep_prob = tf.placeholder(tf.float32, name='keep_prob_input')           # 保持多少不被 dropout
    batch_size = tf.placeholder(tf.int32, [], name='batch_size_input')       # 批大小

# weights and biases
with tf.name_scope('weights'):
    Weights = tf.Variable(tf.truncated_normal([n_hiddens, n_classes],stddev=0.1), dtype=tf.float32, name='W')
    tf.summary.histogram('output_layer_weights', Weights)
with tf.name_scope('biases'):
    biases = tf.Variable(tf.random_normal([n_classes]), name='b')
    tf.summary.histogram('output_layer_biases', biases)

# RNN structure
def RNN_LSTM(x, Weights, biases):
    # RNN 输入 reshape
    x = tf.reshape(x, [-1, n_steps, n_inputs])
    # 定义 LSTM cell
    # cell 中的 dropout
    def attn_cell():
        lstm_cell = tf.contrib.rnn.BasicLSTMCell(n_hiddens)
        with tf.name_scope('lstm_dropout'):
            return tf.contrib.rnn.DropoutWrapper(lstm_cell, output_keep_prob=keep_prob)
    # attn_cell = tf.contrib.rnn.DropoutWrapper(lstm_cell, output_keep_prob=keep_prob)
    # 实现多层 LSTM
    # [attn_cell() for _ in range(n_layers)]
    enc_cells = []
    for i in range(0, n_layers):
        enc_cells.append(attn_cell())
    with tf.name_scope('lstm_cells_layers'):
        mlstm_cell = tf.contrib.rnn.MultiRNNCell(enc_cells, state_is_tuple=True)
    # 全零初始化 state
    _init_state = mlstm_cell.zero_state(batch_size, dtype=tf.float32)
    # dynamic_rnn 运行网络
    outputs, states = tf.nn.dynamic_rnn(mlstm_cell, x, initial_state=_init_state, dtype=tf.float32, time_major=False)
    # 输出
    #return tf.matmul(outputs[:,-1,:], Weights) + biases
    return tf.nn.softmax(tf.matmul(outputs[:,-1,:], Weights) + biases)

with tf.name_scope('output_layer'):
    pred = RNN_LSTM(x, Weights, biases)
    tf.summary.histogram('outputs', pred)
# 损失函数
with tf.name_scope('loss'):
    #cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
    cost = tf.reduce_mean(-tf.reduce_sum(y * tf.log(pred),reduction_indices=[1]))
    tf.summary.scalar('loss', cost)
# 优化器
with tf.name_scope('train'):
    train_op = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
# accuarcy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
#准确率
with tf.name_scope('accuracy'):
    accuracy = tf.metrics.accuracy(labels=tf.argmax(y, axis=1), predictions=tf.argmax(pred, axis=1))[1]
    tf.summary.scalar('accuracy', accuracy)

merged = tf.summary.merge_all()

init = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())

with tf.Session() as sess:
    sess.run(init)
    train_writer = tf.summary.FileWriter("E://logs//train",sess.graph)
    test_writer = tf.summary.FileWriter("E://logs//test",sess.graph)
    # training
    step = 1
    for i in range(10000):
        _batch_size = 128
        batch_x, batch_y = mnist.train.next_batch(_batch_size)

        sess.run(train_op, feed_dict={x:batch_x, y:batch_y, keep_prob:0.5, batch_size:_batch_size})
        if (i + 1) % 100 == 0:
            loss = sess.run(cost, feed_dict={x:batch_x, y:batch_y, keep_prob:1.0, batch_size:_batch_size})
            acc = sess.run(accuracy, feed_dict={x:batch_x, y:batch_y, keep_prob:1.0, batch_size:_batch_size})
            print('Iter: %d' % ((i+1)), '| train loss: %.6f' % loss, '| train accuracy: %.6f' % acc)
            train_result = sess.run(merged, feed_dict={x:batch_x, y:batch_y, keep_prob:1.0, batch_size:_batch_size})
            test_result = sess.run(merged, feed_dict={x:test_x, y:test_y, keep_prob:1.0, batch_size:test_x.shape[0]})
            train_writer.add_summary(train_result,i+1)
            test_writer.add_summary(test_result,i+1)

    print("Optimization Finished!")
    # prediction
    print("Testing Accuracy:", sess.run(accuracy, feed_dict={x:test_x, y:test_y, keep_prob:1.0, batch_size:test_x.shape[0]}))
# Out:
# Extracting E:\sxl_Programs\Python\MNIST_data\MNIST_data\train-images-idx3-ubyte.gz
# Extracting E:\sxl_Programs\Python\MNIST_data\MNIST_data\train-labels-idx1-ubyte.gz
# Extracting E:\sxl_Programs\Python\MNIST_data\MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting E:\sxl_Programs\Python\MNIST_data\MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter: 100 | train loss: 0.304813 | train accuracy: 0.906250
# Iter: 200 | train loss: 0.175098 | train accuracy: 0.873844
# Iter: 300 | train loss: 0.105073 | train accuracy: 0.904797
# Iter: 400 | train loss: 0.092941 | train accuracy: 0.922450
# Iter: 500 | train loss: 0.103112 | train accuracy: 0.931498
# Iter: 600 | train loss: 0.140602 | train accuracy: 0.938959
# Iter: 700 | train loss: 0.170369 | train accuracy: 0.942738
# Iter: 800 | train loss: 0.074613 | train accuracy: 0.945495
# Iter: 900 | train loss: 0.048748 | train accuracy: 0.948890
# Iter: 1000 | train loss: 0.088646 | train accuracy: 0.951413
# Iter: 1100 | train loss: 0.052197 | train accuracy: 0.953549
# Iter: 1200 | train loss: 0.042220 | train accuracy: 0.955544
# Iter: 1300 | train loss: 0.063022 | train accuracy: 0.957183
# Iter: 1400 | train loss: 0.046243 | train accuracy: 0.958735
# Iter: 1500 | train loss: 0.174353 | train accuracy: 0.960163
# Iter: 1600 | train loss: 0.009501 | train accuracy: 0.961537
# Iter: 1700 | train loss: 0.036746 | train accuracy: 0.962807
# Iter: 1800 | train loss: 0.019892 | train accuracy: 0.963904
# Iter: 1900 | train loss: 0.050860 | train accuracy: 0.964755
# Iter: 2000 | train loss: 0.041614 | train accuracy: 0.965470
# Iter: 2100 | train loss: 0.064547 | train accuracy: 0.966134
# Iter: 2200 | train loss: 0.004969 | train accuracy: 0.966799
# Iter: 2300 | train loss: 0.071630 | train accuracy: 0.967452
# Iter: 2400 | train loss: 0.028598 | train accuracy: 0.967917
# Iter: 2500 | train loss: 0.022046 | train accuracy: 0.968454
# Iter: 2600 | train loss: 0.022346 | train accuracy: 0.968834
# Iter: 2700 | train loss: 0.036183 | train accuracy: 0.969241
# Iter: 2800 | train loss: 0.126039 | train accuracy: 0.969856
# Iter: 2900 | train loss: 0.034520 | train accuracy: 0.970306
# Iter: 3000 | train loss: 0.060264 | train accuracy: 0.970835
# Iter: 3100 | train loss: 0.020329 | train accuracy: 0.971180
# Iter: 3200 | train loss: 0.040593 | train accuracy: 0.971578
# Iter: 3300 | train loss: 0.067856 | train accuracy: 0.971768
# Iter: 3400 | train loss: 0.019077 | train accuracy: 0.972045
# Iter: 3500 | train loss: 0.061292 | train accuracy: 0.972385
# Iter: 3600 | train loss: 0.095381 | train accuracy: 0.972717
# Iter: 3700 | train loss: 0.086592 | train accuracy: 0.972979
# Iter: 3800 | train loss: 0.004438 | train accuracy: 0.973211
# Iter: 3900 | train loss: 0.004914 | train accuracy: 0.973490
# Iter: 4000 | train loss: 0.035251 | train accuracy: 0.973760
# Iter: 4100 | train loss: 0.016535 | train accuracy: 0.973972
# Iter: 4200 | train loss: 0.008022 | train accuracy: 0.974162
# Iter: 4300 | train loss: 0.023862 | train accuracy: 0.974371
# Iter: 4400 | train loss: 0.010486 | train accuracy: 0.974595
# Iter: 4500 | train loss: 0.031258 | train accuracy: 0.974787
# Iter: 4600 | train loss: 0.003150 | train accuracy: 0.974994
# Iter: 4700 | train loss: 0.001402 | train accuracy: 0.975192
# Iter: 4800 | train loss: 0.004595 | train accuracy: 0.975348
# Iter: 4900 | train loss: 0.003748 | train accuracy: 0.975563
# Iter: 5000 | train loss: 0.047065 | train accuracy: 0.975742
# Iter: 5100 | train loss: 0.002623 | train accuracy: 0.975891
# Iter: 5200 | train loss: 0.021009 | train accuracy: 0.976035
# Iter: 5300 | train loss: 0.068171 | train accuracy: 0.976190
# Iter: 5400 | train loss: 0.058173 | train accuracy: 0.976347
# Iter: 5500 | train loss: 0.022875 | train accuracy: 0.976404
# Iter: 5600 | train loss: 0.044681 | train accuracy: 0.976539
# Iter: 5700 | train loss: 0.093474 | train accuracy: 0.976596
# Iter: 5800 | train loss: 0.031869 | train accuracy: 0.976601
# Iter: 5900 | train loss: 0.059987 | train accuracy: 0.976725
# Iter: 6000 | train loss: 0.097034 | train accuracy: 0.976834
# Iter: 6100 | train loss: 0.094616 | train accuracy: 0.976888
# Iter: 6200 | train loss: 0.010536 | train accuracy: 0.976984
# Iter: 6300 | train loss: 0.072073 | train accuracy: 0.977074
# Iter: 6400 | train loss: 0.028161 | train accuracy: 0.977165
# Iter: 6500 | train loss: 0.014956 | train accuracy: 0.977268
# Iter: 6600 | train loss: 0.089465 | train accuracy: 0.977422
# Iter: 6700 | train loss: 0.049707 | train accuracy: 0.977522
# Iter: 6800 | train loss: 0.014872 | train accuracy: 0.977564
# Iter: 6900 | train loss: 0.119784 | train accuracy: 0.977656
# Iter: 7000 | train loss: 0.057187 | train accuracy: 0.977751
# Iter: 7100 | train loss: 0.007920 | train accuracy: 0.977790
# Iter: 7200 | train loss: 0.029566 | train accuracy: 0.977873
# Iter: 7300 | train loss: 0.057957 | train accuracy: 0.977930
# Iter: 7400 | train loss: 0.046475 | train accuracy: 0.977973
# Iter: 7500 | train loss: 0.044599 | train accuracy: 0.978042
# Iter: 7600 | train loss: 0.003445 | train accuracy: 0.978090
# Iter: 7700 | train loss: 0.018488 | train accuracy: 0.978133
# Iter: 7800 | train loss: 0.006836 | train accuracy: 0.978217
# Iter: 7900 | train loss: 0.013610 | train accuracy: 0.978291
# Iter: 8000 | train loss: 0.073092 | train accuracy: 0.978370
# Iter: 8100 | train loss: 0.026984 | train accuracy: 0.978416
# Iter: 8200 | train loss: 0.070534 | train accuracy: 0.978445
# Iter: 8300 | train loss: 0.006835 | train accuracy: 0.978525
# Iter: 8400 | train loss: 0.019075 | train accuracy: 0.978602
# Iter: 8500 | train loss: 0.138454 | train accuracy: 0.978646
# Iter: 8600 | train loss: 0.001937 | train accuracy: 0.978664
# Iter: 8700 | train loss: 0.088649 | train accuracy: 0.978704
# Iter: 8800 | train loss: 0.090907 | train accuracy: 0.978770
# Iter: 8900 | train loss: 0.067380 | train accuracy: 0.978805
# Iter: 9000 | train loss: 0.001490 | train accuracy: 0.978880
# Iter: 9100 | train loss: 0.004028 | train accuracy: 0.978885
# Iter: 9200 | train loss: 0.117533 | train accuracy: 0.978947
# Iter: 9300 | train loss: 0.024494 | train accuracy: 0.978951
# Iter: 9400 | train loss: 0.071766 | train accuracy: 0.978983
# Iter: 9500 | train loss: 0.092010 | train accuracy: 0.979000
# Iter: 9600 | train loss: 0.159709 | train accuracy: 0.979048
# Iter: 9700 | train loss: 0.033925 | train accuracy: 0.979041
# Iter: 9800 | train loss: 0.063380 | train accuracy: 0.979092
# Iter: 9900 | train loss: 0.054418 | train accuracy: 0.979104
# Iter: 10000 | train loss: 0.031220 | train accuracy: 0.979113
# Optimization Finished!
# Testing Accuracy: 0.97916764
